# %%
import pandas as pd
import scanpy as sc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import os
import re

# %%
out_dir = "output"
os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# ## Reading in the clinical data for patients

# %%
df = pd.read_excel('./INPUT/Daten_HHGNRegistry_JE_UKEbox_250430.xlsx')
df
# Out:
#    P-Number Xenium Nr.  Alter (Jahre) Geschlecht       Fall  \
# 0       NaN         X6             81   männlich  N00828/16
# 1       NaN         X3             55   weiblich  N03398/16
# 2       NaN         X4             59   männlich  N03552/16
# 3       NaN        X17             72   weiblich  N00194/17
# 4       NaN        X25             52   männlich  N00554/17
# ..      ...        ...            ...        ...        ...
# 72      NaN        NaN             31   weiblich  R02511/22
# 73      NaN        X55             38   weiblich  R02672/18
# 74      NaN        NaN             39   weiblich  R02961/22
# 75      NaN        NaN             42   weiblich  R03259/22
# 76      NaN        NaN             17   weiblich  R03373/22
#
#    Time Bx-Lab (days) Albuminurie g/g Serum-kreatinin        eGFR   C3  ...  \
# 0                  na            0.01             1.2          55  NaN  ...
# 1                   5            0.44             1.6          35       ...
# 2                   7             1.2             2.4       28.26  NaN  ...
# 3                  -2           0.425             1.1       49.93  NaN  ...
# 4                  -1            3.25             3.7       17.59  NaN  ...
# ..                ...             ...             ...         ...  ...  ...
# 72                  0           0.386            0.78  101.620003   13  ...
# 73                 na              na              na          na   na  ...
# 74                 -3           0.034            0.81   91.139999   70  ...
# 75                  1           7.571            0.98   71.379997  NaN  ...
# 76                  0           1.675       17.639999        2.57   66  ...
#
#    ds DNA  Treatmen7 days prior to biopsy Sl_num      Disease Pathology_num  \
# 0      ---            Steroid (75mg oral)      1         ANCA     N00828/16
# 1                   Steroid (2x70mg oral)      2         ANCA     N03398/16
# 2      NaN                          naive      3         ANCA     N03552/16
# 3      NaN     Steroid (3x unklare Dosis)      4         ANCA     N00194/17
# 4      NaN                Steroid (2x500)      5         ANCA     N00554/17
# ..     ...                            ...    ...          ...           ...
# 72     187                            NaN     24  SLE-Reserve     R02511/22
# 73     NaN                             na     22  SLE-Reserve     R02672/18
# 74     206                            NaN     25  SLE-Reserve     R02961/22
# 75     NaN                            NaN     26  SLE-Reserve     R03259/22
# 76     398                            NaN     27  SLE-Reserve     R03373/22
#
#    GNregistry_num   ARRscore_SLEclass Unnamed: 23  Unnamed: 24 Unnamed: 25
# 0         16_0828     ARRS low (0/11)         NaN          NaN     low:  7
# 1         16_3398  ARRS medium (2/11)         NaN          NaN     med: 16
# 2         16_3552  ARRS medium (2/11)         NaN          NaN     high: 6
# 3         17_0194     ARRS low (0/11)         NaN          NaN         NaN
# 4         17_0554    ARRS high (8/11)         NaN          NaN         NaN
# ..            ...                 ...         ...          ...         ...
# 72        22_2511                 NaN         NaN          NaN         NaN
# 73        18_2672         Klasse IV+V         NaN          NaN         NaN
# 74        22_2961                 NaN         NaN          NaN         NaN
# 75        22_3259                 NaN         NaN          NaN         NaN
# 76        22_3373                 NaN         NaN          NaN         NaN
#
# [77 rows x 26 columns]

# %%
df = df.iloc[:,:-3] # removing the last 3 additinal empty columns

# %%
df = df[df['Xenium Nr.'].notna()]
df
# Out:
#    P-Number Xenium Nr.  Alter (Jahre) Geschlecht       Fall  \
# 0       NaN         X6             81   männlich  N00828/16
# 1       NaN         X3             55   weiblich  N03398/16
# 2       NaN         X4             59   männlich  N03552/16
# 3       NaN        X17             72   weiblich  N00194/17
# 4       NaN        X25             52   männlich  N00554/17
# 5       NaN        X27             46   männlich  N00669/17
# 6      P001        X18             43   männlich  N00929/17
# 7       NaN        X33             65   männlich  N01352/17
# 8       NaN        X28             47   männlich  N01359/17
# 9       NaN        X50             24   weiblich  N01376/17
# 10     P004        X59             61   weiblich  N01462/17
# 11      NaN        X36             60   männlich  N02712/17
# 12      NaN        X35             51   männlich  N02792/17
# 14      NaN        X37             56   männlich  R03218/17
# 15      NaN        X26             48   männlich  R03240/17
# 16      NaN        X43             57   männlich  R00044/18
# 18      NaN        X44             63   weiblich  R00557/18
# 19      NaN        X45             78   männlich  R00836/18
# 20      NaN        X19             83   männlich  R00891/18
# 21      NaN        X58             69   weiblich  R01576/18
# 22      NaN        X63             19   weiblich  R02218/18
# 23      NaN        X20             52   männlich  R02251/18
# 25      NaN        X11             51   weiblich  R02487/18
# 26      NaN        X51             57   weiblich  R02792/18
# 27     P020        X52             54   männlich  R02835/18
# 28      NaN        X12             73   männlich  R02886/18
# 29      NaN        X34             75   weiblich  R03153/18
# 30      NaN        X60             49   männlich  R00209/19
# 31      NaN        X53             54   männlich  R00344/19
# 33      NaN        X49             52   männlich  R00960/19
# 34     P029        X42             64   männlich  R01163/19
# 38      NaN        X14             55   weiblich  R00924/20
# 43      NaN         X5             76   männlich  R01681/18
# 44      NaN        X13             26   männlich  R00570/19
# 45      NaN        X38             56   weiblich  R00683/19
# 47      NaN        X21             66   männlich  R01300/20
# 48      NaN        X46             23   weiblich  R01723/20
# 49      NaN        X29             59   männlich  R03080/21
# 52      NaN         X7             54   männlich  N03027/15
# 53      NaN         X8             25   weiblich  N01800/16
# 54      NaN        X15             30   weiblich  N02671/17
# 55      NaN        X16             32   weiblich  R00439/18
# 56      NaN        X22             26   weiblich  R00987/18
# 57      NaN        X30             56   männlich  R02565/18
# 58      NaN        X23             35   weiblich  R00546/19
# 59      NaN        X32             63   männlich  R00567/19
# 60      NaN        X31             42   weiblich  R01807/19
# 61      NaN        X24             38   weiblich  R01377/20
# 62      NaN        X47             33   weiblich  R01967/20
# 63      NaN        X48             51   weiblich  R02332/20
# 64      NaN        X40             34   weiblich  R02488/20
# 65      NaN        X39             38   weiblich  R00464/21
# 66      NaN        X54             20   männlich  R00943/21
# 68      NaN        X56             37   weiblich  R01918/21
# 69      NaN        X61             29   weiblich  R00272/22
# 70      NaN        X62             21   männlich  R01169/22
# 73      NaN        X55             38   weiblich  R02672/18
#
#    Time Bx-Lab (days) Albuminurie g/g Serum-kreatinin        eGFR    C3  ...  \
# 0                  na            0.01             1.2          55   NaN  ...
# 1                   5            0.44             1.6          35        ...
# 2                   7             1.2             2.4       28.26   NaN  ...
# 3                  -2           0.425             1.1       49.93   NaN  ...
# 4                  -1            3.25             3.7       17.59   NaN  ...
# 5                   0            0.76             4.7       13.74   NaN  ...
# 6                   0              na             3.3       21.52   NaN  ...
# 7                  -2              na              na          na   NaN  ...
# 8                   2              na            2.58       28.17   NaN  ...
# 9                   0              na            0.63      125.07   NaN  ...
# 10                  0           0.984             4.3       10.23   NaN  ...
# 11                 -1               4             3.6   17.309999   NaN  ...
# 12                  0             2.1             1.6   49.150002   NaN  ...
# 14                  0            2.93            3.98       15.55    96  ...
# 15                 -6             4.4            3.32       20.77  1,24  ...
# 16                  0           1.369             2.1       33.68   NaN  ...
# 18                  1           0.124             4.2       10.53   NaN  ...
# 19                  0            1.96             2.5   23.540001   NaN  ...
# 20                  0            0.18            2.15       27.27   NaN  ...
# 21                  0           0.361             6.3        6.18   NaN  ...
# 22                  1            0.59              11        4.51   NaN  ...
# 23                 -9            0.74            2.03   36.599998   NaN  ...
# 25                  0             NaN             3.6        13.8   NaN  ...
# 26                  4            0.38             7.5           5   NaN  ...
# 27                 -1           0.155             1.7   44.720001   NaN  ...
# 28                 -4           4.058             2.4   25.790001   NaN  ...
# 29                 19             2.2             3.2       13.44   NaN  ...
# 30                 15            2.09             1.5   53.509998        ...
# 31                 -2            0.97               9        5.92   132  ...
# 33                  0             1.2             2.7          26   NaN  ...
# 34                  0           1.132             1.9   36.189999   NaN  ...
# 38                  1           0.172            1.86   29.809999   NaN  ...
# 43                  0            15.2             1.9          11   NaN  ...
# 44                  2            1.73             9.4        6.84   NaN  ...
# 45                  6            0.55               2   27.309999   NaN  ...
# 47                 na              na              na          na   NaN  ...
# 48                 -3            0.25            1.95       35.25   NaN  ...
# 49                 na              na            4.21          14   NaN  ...
# 52                 na              na              na          na    na  ...
# 53                  0           3.265            0.82   97.690002    55  ...
# 54                 na            1.94             1.1          67    90  ...
# 55                 na            2.13               2          32    27  ...
# 56                  0            0.42            0.54  130.649994    na  ...
# 57                  0               3             1.2   67.190002    85  ...
# 58                 na              na              na          na    na  ...
# 59                 na            2.03             1.4          53    88  ...
# 60                  0           0.113             0.6         112    64  ...
# 61                  2           0.274            0.49  123.120003    34  ...
# 62                 17           0.137            0.86   89.040001    94  ...
# 63                 na              na              na          na    na  ...
# 64                  0             1.1            0.66  114.809998    47  ...
# 65                 21            2.03            1.51   43.220001    78  ...
# 66                  1            0.33             1.1   95.449997    31  ...
# 68                  0           0.212             0.9   81.949997    88  ...
# 69                  8            3.42            0.87       89.68    23  ...
# 70                  0           0.115            2.68   32.299999    50  ...
# 73                 na              na              na          na    na  ...
#
#    cANCA IFT PR3 ELISA   GBM ds DNA     Treatmen7 days prior to biopsy Sl_num  \
# 0        ---       127   ---     ---               Steroid (75mg oral)      1
# 1         na        na                           Steroid (2x70mg oral)      2
# 2        ---       ---   NaN     NaN                             naive      3
# 3        ---       ---   NaN     NaN        Steroid (3x unklare Dosis)      4
# 4        ---       ---   NaN     NaN                   Steroid (2x500)      5
# 5        640       ---   NaN     NaN              Steroid (100mg p.o.)      6
# 6       ----       ---   NaN     NaN                             naive      7
# 7         na        na   NaN     NaN                                na      8
# 8        ---       6,7   NaN    45,4                                na      9
# 9         na        na   NaN     NaN                                na     10
# 10       ---        24   NaN     NaN                    Steroid(1x500)     11
# 11       ---       ---   NaN     NaN                   Steroid (1x500)     12
# 12       ---       ---   NaN     NaN                   Steroid (1x500)     13
# 14        na        na   NaN    28,4                                na     15
# 15       ---       1,1   NaN     NaN                                na     16
# 16        na        na   NaN     NaN                                na     17
# 18       ---       ---   NaN     NaN                   Steroid (3x500)     19
# 19        na        na   NaN     NaN                                na     20
# 20        na        na   NaN     NaN                                na     21
# 21      1000       200   NaN     9,8                                na     22
# 22       ---        70   NaN     NaN                   Steroid (1x250)     23
# 23       ---       ---   NaN     NaN                      MMF (2x1000)     24
# 25       320       200   NaN     NaN                                na     26
# 26       ---       ---   NaN     NaN              Steroid (3x500+oral)     27
# 27      1000       NaN   NaN     NaN             Steroid (1x1g, 2x500)     28
# 28        na       0,6   NaN     NaN                                na     29
# 29       ---       ---   NaN     NaN                             naive     30
# 30       ---       ---                                              na     31
# 31        na       1,6   0,6     NaN                                na     32
# 33       ---       ---   NaN     NaN  Steroid (7mg, RTX vor 2 Monaten)     34
# 34       ---        58   NaN     NaN                   Steroid (3x500)     35
# 38       ---        93   NaN     NaN                  Steroid (1x500?)     39
# 43       NaN       NaN  1124     NaN                             naive      1
# 44       NaN       NaN   406     NaN                   teride+CYC oral      2
# 45       NaN       NaN    12     NaN         Steroid (70mg p.o. daily)      3
# 47       NaN       NaN    na     NaN                                na      5
# 48       NaN       NaN   160     NaN             Steroid+PLEX+CYC p.o.      6
# 49       NaN       NaN    46     NaN             Steroid+PLEX+CYC i.v.      7
# 52                 NaN   NaN      na                                na      3
# 53       NaN       NaN   NaN     302                               AZA      4
# 54       NaN       NaN   NaN      42               Steroid (40mg p.o.)      5
# 55       NaN       NaN   NaN     174               Steroid (2x500i.v.)      6
# 56       NaN       NaN   NaN     200                    MTX+HCQ+Pred 5      7
# 57       NaN       NaN   NaN     2.8         Steroid (30mp p.o. daily)      8
# 58       NaN       NaN   NaN      na                                na      9
# 59       NaN       NaN   NaN      50                        a.e. naive     10
# 60       NaN       NaN   NaN     379      Steroid (p.o. unklare dosis)     11
# 61       NaN       NaN   NaN      13            HCQ+Steroid (2mg p.o.)     12
# 62       NaN       NaN   NaN     7,2                               HCQ     13
# 63       NaN       NaN   NaN      na                                na     14
# 64       NaN       NaN   NaN     379         HCQ+MMF+Steroid (100i.v.)     15
# 65       NaN       NaN   NaN      38                MMF+Steroid (60mg)     16
# 66       NaN       NaN   NaN     513                               HCQ     17
# 68       NaN       NaN   NaN      13            AZA, HCQ+Steroid (5mg)     19
# 69       NaN       NaN   NaN     379                 MMF+Steroid (5mg)     20
# 70       NaN       NaN   NaN      55             HCQ+MMF+Steroid(20mg)     21
# 73       NaN       NaN   NaN     NaN                                na     22
#
#         Disease Pathology_num  GNregistry_num     ARRscore_SLEclass
# 0          ANCA     N00828/16         16_0828       ARRS low (0/11)
# 1          ANCA     N03398/16         16_3398    ARRS medium (2/11)
# 2          ANCA     N03552/16         16_3552    ARRS medium (2/11)
# 3          ANCA     N00194/17         17_0194       ARRS low (0/11)
# 4          ANCA     N00554/17         17_0554      ARRS high (8/11)
# 5          ANCA     N00669/17         17_0669    ARRS medium (5/11)
# 6          ANCA     N00929/17         17_0929    ARRS medium (2/11)
# 7          ANCA     N01352/17         17_1352                    na
# 8          ANCA     N01359/17         17_1359    ARRS medium (2/11)
# 9          ANCA     N01376/17         17_1376       ARRS low (0/11)
# 10         ANCA     N01462/17         17_1462      ARRS high (9/11)
# 11         ANCA     N02712/17         17_2712    ARRS medium (4/11)
# 12         ANCA     N02792/17         17_2792    ARRS medium (2(11)
# 14         ANCA     R03218/17         17_3218      ARRS high (9/11)
# 15         ANCA     R03240/17         17_3240    ARRS medium (6/11)
# 16         ANCA     R00044/18         18_0044       ARRS low (0/11)
# 18         ANCA     R00557/18         18_0557      ARRS high (5/11)
# 19         ANCA     R00836/18         18_0836    ARRS medium (2/11)
# 20         ANCA     R00891/18         18_0891    ARRS medium (6/11)
# 21         ANCA     R01576/18         18_1576    ARRS medium (3/11)
# 22         ANCA     R02218/18         18_2218      ARRS high (9/11)
# 23         ANCA     R02251/18         18_2251    ARRS medium (6/11)
# 25         ANCA     R02487/18         18_2487    ARRS medium (5/11)
# 26         ANCA     R02792/18         18_2792     ARRS high (11/11)
# 27         ANCA     R02835/18         18_2835       ARRS low (0/11)
# 28         ANCA     R02886/18         18_2886       ARRS low (0/11)
# 29         ANCA     R03153/18         18_3153    ARRS medium (3/11)
# 30         ANCA     R00209/19         19_0209    ARRS medium (2/11)
# 31         ANCA     R00344/19         19_0344     ARRS high (11/11)
# 33         ANCA     R00960/19         19_0960     ARRS high (11/11)
# 34         ANCA     R01163/19         19_1163    ARRS medium (2/11)
# 38         ANCA     R00924/20         20_0924       ARRS low (0/11)
# 43          GBM     R01681/18         18_1681    100% glom affected
# 44          GBM     R00570/19         19_0570    82% gloms affected
# 45          GBM     R00683/19         19_0683  55,6% gloms affected
# 47          GBM     R01300/20         20_1300    >95%gloms affected
# 48          GBM     R01723/20         20_1723  61,5% gloms affected
# 49          GBM     R03080/21         21_3080  86,8% gloms affected
# 52         SLE      N03027/15         15_3027           Klasse IIIa
# 53         SLE      N01800/16         16_1800          Klasse III+V
# 54         SLE      N02671/17         17_2671            Klasse III
# 55         SLE      R00439/18         18_0439             Klasse IV
# 56         SLE      R00987/18         18_0987           Klasse IIIa
# 57         SLE      R02565/18         18_2565          Klasse III+V
# 58         SLE      R00546/19         19_0546          Klasse III+V
# 59         SLE      R00567/19         19_0567           Klasse IV+V
# 60         SLE      R01807/19         19_1807            Klasse III
# 61         SLE      R01377/20         20_1377          Klasse III+V
# 62         SLE      R01967/20         20_1967            Klasse III
# 63         SLE      R02332/20         20_2332
# 64         SLE      R02488/20         20_2488            Klasse III
# 65         SLE      R00464/21         21_0464             Klasse IV
# 66         SLE      R00943/21         21_0943             Klasse IV
# 68         SLE      R01918/21         21_1918            Klasse III
# 69         SLE      R00272/22         22_0272          Klasse III+V
# 70         SLE      R01169/22         22_1169             Klasse IV
# 73  SLE-Reserve     R02672/18         18_2672           Klasse IV+V
#
# [57 rows x 23 columns]

# %% [markdown]
# ## Subsetting columns from clinical data

# %%
#PatientData_plotting = df.drop(columns = ['P-Number','Fall','Time Bx-Lab (days)','C3', 'C4', 'pANCA IFT', 'pANCA ELISA', 'cANCA IFT', 'cANCA ELISA','GBM', 'ds DNA ', 'Treatmen7 days prior to biopsy', 'Sl_num','Pathology_num',
#       'GNregistry_num'])
#Was giving this error: KeyError: "['pANCA ELISA', 'cANCA ELISA'] not found in axis"

PatientData_plotting = df.drop(columns = ['P-Number','Fall','Time Bx-Lab (days)','C3', 'C4', 'pANCA IFT', 'MPO ELISA', 'cANCA IFT', 'PR3 ELISA','GBM', 'ds DNA ', 'Treatmen7 days prior to biopsy', 'Sl_num','Pathology_num',
       'GNregistry_num'])

PatientData_plotting['Xenium Nr.'] = PatientData_plotting['Xenium Nr.'].str.replace(r'\(.*?\)', '', regex=True) # removing the (?) from X54

# %%
x_list = [f'X{i}' for i in range(1, 64)]

missing_values = set(x_list) - set(PatientData_plotting['Xenium Nr.'])
missing_values

# 1,2,9,10,41,57 are controls.
# Out:
# {'X1', 'X10', 'X2', 'X41', 'X57', 'X9'}

# %%
print(PatientData_plotting.eGFR.dtype)
# Out:
# object

# %% [markdown]
# ## Clean up columns for plotting

# %%
columns_to_convert = ['Albuminurie g/g', 'Serum-kreatinin', 'eGFR']

for column in columns_to_convert:
    # Replace 'na' and other problematic strings with np.nan
    PatientData_plotting[column] = PatientData_plotting[column].replace(['na', 'NaN', None], np.nan)

    # Convert column to numeric, coercing errors into NaN
    PatientData_plotting[column] = pd.to_numeric(PatientData_plotting[column], errors='coerce')

    # Optional: Convert to nullable integer type if needed
    #PatientData_plotting[column] = PatientData_plotting[column].astype('Int64')  # If you want integers with NaNs allowed


# Check updated DataFrame
print(PatientData_plotting.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57 entries, 0 to 73
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Xenium Nr.         57 non-null     object
#  1   Alter (Jahre)      57 non-null     int64
#  2   Geschlecht         57 non-null     object
#  3   Albuminurie g/g    46 non-null     float64
#  4   Serum-kreatinin    51 non-null     float64
#  5   eGFR               51 non-null     float64
#  6   Disease            57 non-null     object
#  7   ARRscore_SLEclass  57 non-null     object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 4.0+ KB
# None
# /tmp/ipykernel_11045/2266689106.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   PatientData_plotting[column] = PatientData_plotting[column].replace(['na', 'NaN', None], np.nan)

# %%
print(PatientData_plotting.eGFR.dtype)
# Out:
# float64

# %%
PatientData_plotting
# Out:
#    Xenium Nr.  Alter (Jahre) Geschlecht  Albuminurie g/g  Serum-kreatinin  \
# 0          X6             81   männlich            0.010             1.20
# 1          X3             55   weiblich            0.440             1.60
# 2          X4             59   männlich            1.200             2.40
# 3         X17             72   weiblich            0.425             1.10
# 4         X25             52   männlich            3.250             3.70
# 5         X27             46   männlich            0.760             4.70
# 6         X18             43   männlich              NaN             3.30
# 7         X33             65   männlich              NaN              NaN
# 8         X28             47   männlich              NaN             2.58
# 9         X50             24   weiblich              NaN             0.63
# 10        X59             61   weiblich            0.984             4.30
# 11        X36             60   männlich            4.000             3.60
# 12        X35             51   männlich            2.100             1.60
# 14        X37             56   männlich            2.930             3.98
# 15        X26             48   männlich            4.400             3.32
# 16        X43             57   männlich            1.369             2.10
# 18        X44             63   weiblich            0.124             4.20
# 19        X45             78   männlich            1.960             2.50
# 20        X19             83   männlich            0.180             2.15
# 21        X58             69   weiblich            0.361             6.30
# 22        X63             19   weiblich            0.590            11.00
# 23        X20             52   männlich            0.740             2.03
# 25        X11             51   weiblich              NaN             3.60
# 26        X51             57   weiblich            0.380             7.50
# 27        X52             54   männlich            0.155             1.70
# 28        X12             73   männlich            4.058             2.40
# 29        X34             75   weiblich            2.200             3.20
# 30        X60             49   männlich            2.090             1.50
# 31        X53             54   männlich            0.970             9.00
# 33        X49             52   männlich            1.200             2.70
# 34        X42             64   männlich            1.132             1.90
# 38        X14             55   weiblich            0.172             1.86
# 43         X5             76   männlich           15.200             1.90
# 44        X13             26   männlich            1.730             9.40
# 45        X38             56   weiblich            0.550             2.00
# 47        X21             66   männlich              NaN              NaN
# 48        X46             23   weiblich            0.250             1.95
# 49        X29             59   männlich              NaN             4.21
# 52         X7             54   männlich              NaN              NaN
# 53         X8             25   weiblich            3.265             0.82
# 54        X15             30   weiblich            1.940             1.10
# 55        X16             32   weiblich            2.130             2.00
# 56        X22             26   weiblich            0.420             0.54
# 57        X30             56   männlich            3.000             1.20
# 58        X23             35   weiblich              NaN              NaN
# 59        X32             63   männlich            2.030             1.40
# 60        X31             42   weiblich            0.113             0.60
# 61        X24             38   weiblich            0.274             0.49
# 62        X47             33   weiblich            0.137             0.86
# 63        X48             51   weiblich              NaN              NaN
# 64        X40             34   weiblich            1.100             0.66
# 65        X39             38   weiblich            2.030             1.51
# 66        X54             20   männlich            0.330             1.10
# 68        X56             37   weiblich            0.212             0.90
# 69        X61             29   weiblich            3.420             0.87
# 70        X62             21   männlich            0.115             2.68
# 73        X55             38   weiblich              NaN              NaN
#
#           eGFR      Disease     ARRscore_SLEclass
# 0    55.000000         ANCA       ARRS low (0/11)
# 1    35.000000         ANCA    ARRS medium (2/11)
# 2    28.260000         ANCA    ARRS medium (2/11)
# 3    49.930000         ANCA       ARRS low (0/11)
# 4    17.590000         ANCA      ARRS high (8/11)
# 5    13.740000         ANCA    ARRS medium (5/11)
# 6    21.520000         ANCA    ARRS medium (2/11)
# 7          NaN         ANCA                    na
# 8    28.170000         ANCA    ARRS medium (2/11)
# 9   125.070000         ANCA       ARRS low (0/11)
# 10   10.230000         ANCA      ARRS high (9/11)
# 11   17.309999         ANCA    ARRS medium (4/11)
# 12   49.150002         ANCA    ARRS medium (2(11)
# 14   15.550000         ANCA      ARRS high (9/11)
# 15   20.770000         ANCA    ARRS medium (6/11)
# 16   33.680000         ANCA       ARRS low (0/11)
# 18   10.530000         ANCA      ARRS high (5/11)
# 19   23.540001         ANCA    ARRS medium (2/11)
# 20   27.270000         ANCA    ARRS medium (6/11)
# 21    6.180000         ANCA    ARRS medium (3/11)
# 22    4.510000         ANCA      ARRS high (9/11)
# 23   36.599998         ANCA    ARRS medium (6/11)
# 25   13.800000         ANCA    ARRS medium (5/11)
# 26    5.000000         ANCA     ARRS high (11/11)
# 27   44.720001         ANCA       ARRS low (0/11)
# 28   25.790001         ANCA       ARRS low (0/11)
# 29   13.440000         ANCA    ARRS medium (3/11)
# 30   53.509998         ANCA    ARRS medium (2/11)
# 31    5.920000         ANCA     ARRS high (11/11)
# 33   26.000000         ANCA     ARRS high (11/11)
# 34   36.189999         ANCA    ARRS medium (2/11)
# 38   29.809999         ANCA       ARRS low (0/11)
# 43   11.000000          GBM    100% glom affected
# 44    6.840000          GBM    82% gloms affected
# 45   27.309999          GBM  55,6% gloms affected
# 47         NaN          GBM    >95%gloms affected
# 48   35.250000          GBM  61,5% gloms affected
# 49   14.000000          GBM  86,8% gloms affected
# 52         NaN         SLE            Klasse IIIa
# 53   97.690002         SLE           Klasse III+V
# 54   67.000000         SLE             Klasse III
# 55   32.000000         SLE              Klasse IV
# 56  130.649994         SLE            Klasse IIIa
# 57   67.190002         SLE           Klasse III+V
# 58         NaN         SLE           Klasse III+V
# 59   53.000000         SLE            Klasse IV+V
# 60  112.000000         SLE             Klasse III
# 61  123.120003         SLE           Klasse III+V
# 62   89.040001         SLE             Klasse III
# 63         NaN         SLE
# 64  114.809998         SLE             Klasse III
# 65   43.220001         SLE              Klasse IV
# 66   95.449997         SLE              Klasse IV
# 68   81.949997         SLE             Klasse III
# 69   89.680000         SLE           Klasse III+V
# 70   32.299999         SLE              Klasse IV
# 73         NaN  SLE-Reserve           Klasse IV+V

# %%
na_rows=PatientData_plotting[PatientData_plotting.isna().any(axis=1)]
na_rows
#Can we get these values?
# Out:
#    Xenium Nr.  Alter (Jahre) Geschlecht  Albuminurie g/g  Serum-kreatinin  \
# 6         X18             43   männlich              NaN             3.30
# 7         X33             65   männlich              NaN              NaN
# 8         X28             47   männlich              NaN             2.58
# 9         X50             24   weiblich              NaN             0.63
# 25        X11             51   weiblich              NaN             3.60
# 47        X21             66   männlich              NaN              NaN
# 49        X29             59   männlich              NaN             4.21
# 52         X7             54   männlich              NaN              NaN
# 58        X23             35   weiblich              NaN              NaN
# 63        X48             51   weiblich              NaN              NaN
# 73        X55             38   weiblich              NaN              NaN
#
#       eGFR      Disease     ARRscore_SLEclass
# 6    21.52         ANCA    ARRS medium (2/11)
# 7      NaN         ANCA                    na
# 8    28.17         ANCA    ARRS medium (2/11)
# 9   125.07         ANCA       ARRS low (0/11)
# 25   13.80         ANCA    ARRS medium (5/11)
# 47     NaN          GBM    >95%gloms affected
# 49   14.00          GBM  86,8% gloms affected
# 52     NaN         SLE            Klasse IIIa
# 58     NaN         SLE           Klasse III+V
# 63     NaN         SLE
# 73     NaN  SLE-Reserve           Klasse IV+V

# %%
PatientData_plotting.columns
# Out:
# Index(['Xenium Nr.', 'Alter (Jahre)', 'Geschlecht', 'Albuminurie g/g',
#        'Serum-kreatinin', 'eGFR', 'Disease', 'ARRscore_SLEclass'],
#       dtype='object')

# %%
PatientData_plotting = PatientData_plotting.rename(columns={
    "Xenium Nr.": "biopsy_nr",
    "Alter (Jahre)": "age", 
    "Geschlecht": "sex",
    "Albuminurie g/g": "albuminuria_gg",
    "Serum-kreatinin": "serum_creatinine",
    "Disease": "disease",
    "ARRscore_SLEclass":"ARRscore_SLEclass"
    
})

# %%
PatientData_plotting.head()
# Out:
#   biopsy_nr  age       sex  albuminuria_gg  serum_creatinine   eGFR disease  \
# 0        X6   81  männlich           0.010               1.2  55.00    ANCA
# 1        X3   55  weiblich           0.440               1.6  35.00    ANCA
# 2        X4   59  männlich           1.200               2.4  28.26    ANCA
# 3       X17   72  weiblich           0.425               1.1  49.93    ANCA
# 4       X25   52  männlich           3.250               3.7  17.59    ANCA
#
#     ARRscore_SLEclass
# 0     ARRS low (0/11)
# 1  ARRS medium (2/11)
# 2  ARRS medium (2/11)
# 3     ARRS low (0/11)
# 4    ARRS high (8/11)

# %%
PatientData_plotting.to_csv('INPUT/PatientData_plotting.csv', index=False)

# %%
## Clinical Data for controls

# %%
ControlsData=pd.read_excel('./INPUT/Clinical_Data_HC_JE_Jonas_email_250417.xlsx')

# %%
ControlsData
# Out:
#   Xeniums Slide ID  Histo ID CN-Nr.  Age     Sex  Creatinine [mg/dl]  \
# 0               X1  PA166/23   CN38   54  female                0.57
# 1               X2  PA175/23   CN39   71  female                0.93
# 2               X9  PA172/23   CN39   71  female                0.93
# 3              X10   PA84/23   CN36   61  female                0.72
# 4              X41   PA38/22   CN27   57    male                1.07
# 5              X57   PA85/21   CN18   78    male                1.20
#
#    GFR [ml/min]                          Disease  Unnamed: 8    Unnamed: 9
# 0           106      Liposarcoma retroperitoneal         NaN           NaN
# 1            61      Liposarcoma retroperitoneal         NaN  same patient
# 2            61      Liposarcoma retroperitoneal         NaN           NaN
# 3            90      Transitional cell carcinoma         NaN           NaN
# 4            91  clear cell renal cell carcinoma         NaN           NaN
# 5            63      Transitional cell carcinoma         NaN           NaN

# %%
ControlsData= ControlsData.iloc[:,:-2]

# %%
ControlsData = ControlsData.rename(columns={
    "Xeniums Slide ID": "biopsy_nr",
    "Age": "age", 
    "Sex": "sex",
    "Creatinine [mg/dl]": "serum_creatinine_mg_dl",
    "GFR [ml/min]":"eGFR_ml_min",
    "Disease": "disease"
})

# %%
ControlsData_plotting= ControlsData.drop(columns = ["Histo ID","CN-Nr."])

# %%
ControlsData_plotting
# Out:
#   biopsy_nr  age     sex  serum_creatinine_mg_dl  eGFR_ml_min  \
# 0        X1   54  female                    0.57          106
# 1        X2   71  female                    0.93           61
# 2        X9   71  female                    0.93           61
# 3       X10   61  female                    0.72           90
# 4       X41   57    male                    1.07           91
# 5       X57   78    male                    1.20           63
#
#                            disease
# 0      Liposarcoma retroperitoneal
# 1      Liposarcoma retroperitoneal
# 2      Liposarcoma retroperitoneal
# 3      Transitional cell carcinoma
# 4  clear cell renal cell carcinoma
# 5      Transitional cell carcinoma

# %%
ControlsData_plotting.to_csv('./INPUT/ControlsData_plotting.csv', index=False)

# %% [markdown]
# ## Putting the control and pateint clinical data together

# %%
import pandas as pd

def append_rows_with_matching_columns(df_base, df_to_append, column_map):
    """
    Rename and align df_to_append to match df_base, filling missing columns with NaN.
    
    Parameters:
        df_base (pd.DataFrame): The reference DataFrame with desired column structure.
        df_to_append (pd.DataFrame): The new rows to add (columns may differ).
        column_map (dict): Mapping from df_to_append columns → df_base columns.

    Returns:
        pd.DataFrame: Combined DataFrame with consistent columns.
    """
    # Step 1: Rename df_to_append columns to match df_base
    df_renamed = df_to_append.rename(columns=column_map)

    # Step 2: Add missing columns (fill with NA)
    for col in df_base.columns:
        if col not in df_renamed.columns:
            df_renamed[col] = pd.NA

    # Step 3: Reorder to match df_base
    df_aligned = df_renamed[df_base.columns]

    # Step 4: Concatenate
    combined_df = pd.concat([df_base, df_aligned], ignore_index=True)

    return combined_df

# %%
column_names_matched = {
    "serum_creatinine_mg_dl": "serum_creatinine",
    "eGFR_ml_min": "eGFR"
}

clinical_data_all = append_rows_with_matching_columns(PatientData_plotting,
                                             ControlsData_plotting,
                                             column_map = column_names_matched)
# Out:
# /tmp/ipykernel_11045/2209758065.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([df_base, df_aligned], ignore_index=True)

# %%
clinical_data_all
# Out:
#    biopsy_nr  age       sex  albuminuria_gg  serum_creatinine   eGFR  \
# 0         X6   81  männlich           0.010              1.20  55.00
# 1         X3   55  weiblich           0.440              1.60  35.00
# 2         X4   59  männlich           1.200              2.40  28.26
# 3        X17   72  weiblich           0.425              1.10  49.93
# 4        X25   52  männlich           3.250              3.70  17.59
# ..       ...  ...       ...             ...               ...    ...
# 58        X2   71    female             NaN              0.93  61.00
# 59        X9   71    female             NaN              0.93  61.00
# 60       X10   61    female             NaN              0.72  90.00
# 61       X41   57      male             NaN              1.07  91.00
# 62       X57   78      male             NaN              1.20  63.00
#
#                             disease   ARRscore_SLEclass
# 0                              ANCA     ARRS low (0/11)
# 1                              ANCA  ARRS medium (2/11)
# 2                              ANCA  ARRS medium (2/11)
# 3                              ANCA     ARRS low (0/11)
# 4                              ANCA    ARRS high (8/11)
# ..                              ...                 ...
# 58      Liposarcoma retroperitoneal                 NaN
# 59      Liposarcoma retroperitoneal                 NaN
# 60      Transitional cell carcinoma                 NaN
# 61  clear cell renal cell carcinoma                 NaN
# 62      Transitional cell carcinoma                 NaN
#
# [63 rows x 8 columns]

# %%
clinical_data_all.to_csv(os.path.join(out_dir,"clinical_data_all.csv"), index=False)
