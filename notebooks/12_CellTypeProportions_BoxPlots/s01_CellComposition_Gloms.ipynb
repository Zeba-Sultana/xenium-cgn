# %%
import importlib
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import scanpy as sc
import seaborn as sns

from sccoda.util import comp_ana as mod
from sccoda.util import cell_composition_data as dat
from sccoda.util import data_visualization as viz


import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sccoda.util import data_visualization as viz
# Out:
# 2025-05-24 23:20:50.725374: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-24 23:20:50.765477: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-24 23:20:50.765506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-24 23:20:50.766611: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-24 23:20:50.773000: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-24 23:20:50.773702: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-24 23:20:51.629553: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
out_folder = './output'
os.makedirs(out_folder, exist_ok=True)

# %%
# the following are needed to ensure that text in plt images opens as text box rather than glyphs in adobe
plt.rcParams['pdf.fonttype'] = 42  
plt.rcParams['ps.fonttype'] = 42

# %%
# !pwd
# Out:
# /data/projects/zeba/MY_PROJECTS/240130_Xenium_ANCA_SLE_GBM/xenium-cgn-zeba-may25/xenium-cgn/notebooks/12_CellTypeProportions_BoxPlots

# %% [markdown]
# ## AnnData Object with everything
# Shared by Robin on 31 Oct Slack with me:
# /data/projects/robin/segmentation/xenium_outs/adata_complete_reduced_withTransformedMC.h5ad
# This is also the object that I have used for the Cellchat Analysis

# %%
#adata = sc.read_h5ad("/data/projects/robin/segmentation/xenium_outs/adata_complete_reduced_withTransformedMC.h5ad")
adata = sc.read_h5ad('/data/projects/zeba/MY_PROJECTS/240130_Xenium_ANCA_SLE_GBM/xenium-cgn/notebooks_zs/02_PeriglomDefinition_Sample26updated/output_dataobjects/adata_complete_reduced_withTransformedMC_X26updated.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 3218210 × 480
#     obs: 'x', 'y', 'z', 'cluster', 'n_transcripts', 'density', 'elongation', 'area', 'avg_confidence', 'avg_assignment_confidence', 'max_cluster_frac', 'lifespan', 'x_centroid', 'y_centroid', 'cell_area', 'Slide_ID', 'batch', 'Patient_Sample_ID', 'Disease', 'n_genes', 'celltype_l1', 'celltype_l1_codes', 'celltype_l1_prob', 'Biopsy_ID', 'sample', 'label', 'nichepca_domain', 'nichepca_domain_tuned', 'nichepca_glom_no', 'glom_ID', 'polygon_flags', 'is_in_polygon', 'is_in_glom', 'is_in_periglom', 'Slide_num'
#     var: 'gene_ids', 'feature_types'
#     uns: 'celltype_l1_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'

# %%
rename_dict = {
    "Transformed mesangial": "Fibrotic MC",
    "mesangial cell": "MC",
}


adata.obs["celltype_l1"] = adata.obs["celltype_l1"].replace(rename_dict)

# %% [markdown]
# ### Subset Cell within gloms

# %%
adata=adata[adata.obs['is_in_glom']==True]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 169753 × 480
#     obs: 'x', 'y', 'z', 'cluster', 'n_transcripts', 'density', 'elongation', 'area', 'avg_confidence', 'avg_assignment_confidence', 'max_cluster_frac', 'lifespan', 'x_centroid', 'y_centroid', 'cell_area', 'Slide_ID', 'batch', 'Patient_Sample_ID', 'Disease', 'n_genes', 'celltype_l1', 'celltype_l1_codes', 'celltype_l1_prob', 'Biopsy_ID', 'sample', 'label', 'nichepca_domain', 'nichepca_domain_tuned', 'nichepca_glom_no', 'glom_ID', 'polygon_flags', 'is_in_polygon', 'is_in_glom', 'is_in_periglom', 'Slide_num'
#     var: 'gene_ids', 'feature_types'
#     uns: 'celltype_l1_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'

# %%
adata.obs["Patient_Sample_ID"]
# Out:
# cell_CR4f0dee9aa-1601        X8_SLE
# cell_CR4f0dee9aa-1632        X8_SLE
# cell_CR4f0dee9aa-1642        X8_SLE
# cell_CR4f0dee9aa-1668        X8_SLE
# cell_CR4f0dee9aa-1670        X8_SLE
#                              ...
# cell_CR4113b3b6d-450863    X63_ANCA
# cell_CR4113b3b6d-451014    X58_ANCA
# cell_CR4113b3b6d-451429    X63_ANCA
# cell_CR4113b3b6d-451522    X63_ANCA
# cell_CR4113b3b6d-451974    X60_ANCA
# Name: Patient_Sample_ID, Length: 169753, dtype: category
# Categories (59, object): ['X1_Cntrl', 'X2_Cntrl', 'X3_ANCA', 'X4_ANCA', ..., 'X60_ANCA', 'X61_SLE', 'X62_SLE', 'X63_ANCA']

# %%
df_sample_celltypes = adata.obs[["Patient_Sample_ID","celltype_l1"]]
df_sample_celltypes
# Out:
#                         Patient_Sample_ID  celltype_l1
# cell_CR4f0dee9aa-1601              X8_SLE           PT
# cell_CR4f0dee9aa-1632              X8_SLE           EC
# cell_CR4f0dee9aa-1642              X8_SLE          DTL
# cell_CR4f0dee9aa-1668              X8_SLE  Fibrotic MC
# cell_CR4f0dee9aa-1670              X8_SLE          DTL
# ...                                   ...          ...
# cell_CR4113b3b6d-450863          X63_ANCA          PEC
# cell_CR4113b3b6d-451014          X58_ANCA           MC
# cell_CR4113b3b6d-451429          X63_ANCA  Fibrotic MC
# cell_CR4113b3b6d-451522          X63_ANCA  Fibrotic MC
# cell_CR4113b3b6d-451974          X60_ANCA  Fibrotic MC
#
# [169753 rows x 2 columns]

# %%
df_sampleXcelltypes = df_sample_celltypes.groupby(["Patient_Sample_ID","celltype_l1"]).size().reset_index(name='counts')
df_sampleXcelltypes
# Out:
#      Patient_Sample_ID  celltype_l1  counts
# 0             X1_Cntrl     podocyte    1974
# 1             X1_Cntrl          PEC     313
# 2             X1_Cntrl           MC    1253
# 3             X1_Cntrl  Fibrotic MC      33
# 4             X1_Cntrl         PapE       3
# ...                ...          ...     ...
# 1765          X63_ANCA         MAST      11
# 1766          X63_ANCA          cDC      17
# 1767          X63_ANCA          pDC       2
# 1768          X63_ANCA       cycMNP     462
# 1769          X63_ANCA     cycNKC/T      38
#
# [1770 rows x 3 columns]

# %%
df_sampleXcelltypes = df_sampleXcelltypes.pivot(index= "Patient_Sample_ID", columns="celltype_l1", values="counts").fillna(0)
df_sampleXcelltypes = df_sampleXcelltypes.astype(int)

# %%
df_sampleXcelltypes["Patient_Sample_ID_col"]=df_sampleXcelltypes.index

# %%
df_sampleXcelltypes
# Out:
# celltype_l1        podocyte   PEC    MC  Fibrotic MC  PapE  VSM/P    EC   PT  \
# Patient_Sample_ID
# X1_Cntrl               1974   313  1253           33     3    105  2571   24
# X2_Cntrl                268    43   175           12     1     16   331    2
# X3_ANCA                 365   233    73           70     2     20   306    9
# X4_ANCA                 254    27   158           26     1     71   661    4
# X6_ANCA                 209    38    36            2     0     17   244    1
# X7_SLE                  254    21    70           16     0     21   456    2
# X8_SLE                   38    14     3           16     0      3    31    6
# X9_Cntrl                666   156   369           27     2     26   712   19
# X10_Cntrl              2412   594  1462          149     9    115  2956  133
# X12_ANCA                136   221    50           36     4     37   200    5
# X13_GBM                 382   480    73          653     6    114   225   20
# X14_ANCA                577   156   124          123     2     34   351    5
# X15_SLE                 413   217   184           89     3     95   480    9
# X16_SLE                 489   370   390           58     2    152   884   17
# X17_ANCA                844   305   254          134     8     73   780   12
# X18_ANCA                 54    84    51           13     0      6    96    5
# X19_ANCA                 58    38    10           51     3      8    23    2
# X20_ANCA                 75    23    39           18     2     11    84    0
# X21_GBM                1975  2469   559         2125    54    404  2517  170
# X22_SLE                 887   442   440           77     9    123  1383   12
# X23_SLE                 213     3    59            1     0      5   285    1
# X24_SLE                1727   602   606           74     4     82  3200   33
# X25_ANCA                117   183    72           77     0     30   111    3
# X26_ANCA                424    52   104            0     1     19   605    7
# X27_ANCA                850   899   242          341    13    112   616   42
# X28_ANCA                 87   129    14           19     1      6    99    3
# X29_GBM                1939  2031   513          480    15    128  1461  136
# X30_SLE                 903   219   264           51     5    105   834   15
# X31_SLE                1743   473   341           85     5     51  1519   27
# X32_SLE                 129    53    69           16     0     15   179    3
# X33_ANCA                584   314   155          114     2    108   716    6
# X34_ANCA                490   272   240           47     4     60   604    7
# X35_ANCA                534   182   213          126     4    119   471    7
# X36_ANCA                472   722   199          303     5    138   475   22
# X37_ANCA                534   614   208          286     5     93   722   10
# X38_GBM                 496   176    83          118     3     37   196    3
# X39_SLE                1851   269   466           69     6    120  1686   24
# X40_SLE                 283    74   142           22     0     35   327    3
# X41_Cntrl              1568   779   556          179    18     85  1597  212
# X43_ANCA                355   299    97           87     1     68   283   21
# X44_ANCA                340    99    61           19     4     18   263    4
# X45_ANCA                858   172   161           77     1     70   564   15
# X46_GBM                 286   165    41           83     3     29   172    6
# X47_SLE                 755   590    46           43     3     29   600   42
# X48_SLE                 223    57   217           32     5     49   388    5
# X49_ANCA                586   487   299          175     5    151   778    9
# X50_ANCA                241   121    38           61     3     12   217    2
# X51_ANCA                212   340   108          338     5     64   198    7
# X52_ANCA                549   102    90           37     4     25   509   14
# X53_ANCA               1275  1135   406          856    13    350  1255   56
# X54_SLE                 471   132   324           24     4     84  1071   11
# X55_SLE                1296   591   772          177    14    299  2176   78
# X56_SLE                 381    97    90           62     2     21   304    6
# X57_Cntrl              1914   287   569          113    14    176  2225   60
# X58_ANCA                831   465   223          230     3     80  1029   16
# X60_ANCA                569   436   129          134     5     95   585   26
# X61_SLE                 159    24    75            3     1     14   334    5
# X62_SLE                 239    51   211           27     1     47   445    6
# X63_ANCA               1860  2146   548         1574    51    375  1404   75
#
# celltype_l1        ATL  CNT  ...     N   MAC  MDC  Mono  MAST  cDC  pDC  \
# Patient_Sample_ID            ...
# X1_Cntrl             5    9  ...    18    12   29    97     4    8    2
# X2_Cntrl             0    0  ...     1     3    5    12     1    0    0
# X3_ANCA              0    0  ...     8    30   25    30     1    0    0
# X4_ANCA              0    1  ...    12     6    6    10     1    0    0
# X6_ANCA              1    0  ...     1     1    0     0     0    0    0
# X7_SLE               1    2  ...     8    12    3    13     0    0    0
# X8_SLE               0    0  ...     1     4    0     9     0    1    1
# X9_Cntrl             1    0  ...     4    11    8    17     2    1    1
# X10_Cntrl           14   11  ...    26    31   22    52     5    7    2
# X12_ANCA             1    2  ...     9    10   24    20     1    1    1
# X13_GBM              2    2  ...   120   305  152   134     1    3    1
# X14_ANCA             0    2  ...     8    32   16    15     1    2    1
# X15_SLE              2    2  ...    10    11    8    21     5    5    0
# X16_SLE              3    1  ...    31   174   67    66     2    1    0
# X17_ANCA             3    4  ...    57   153  108    98     3    6    1
# X18_ANCA             1    0  ...     4     2    3     3     1    0    0
# X19_ANCA             0    0  ...     8    67   22    28     0    0    0
# X20_ANCA             0    0  ...     2     3    2     2     3    0    0
# X21_GBM             29   16  ...  1009  4009  776  1226    21   30    4
# X22_SLE              7    8  ...   100   204  127   356     5   11    2
# X23_SLE              0    0  ...    12     1    3    23     1    0    0
# X24_SLE              6    5  ...    47    77   24   155     5    5    2
# X25_ANCA             1    0  ...     4    16   24     7     1    2    0
# X26_ANCA             2    3  ...     6    14   12    19     0    0    0
# X27_ANCA             4    5  ...    76   353  177   105     5    0    1
# X28_ANCA             1    1  ...     4     4   13    16     0    0    1
# X29_GBM             17   11  ...    86   610  241   181     6   12    3
# X30_SLE              3    2  ...    28    45   19    36     2    0    1
# X31_SLE              5    3  ...    37   101   72   131     0    4    0
# X32_SLE              1    1  ...    10     5   18    22     0    1    0
# X33_ANCA             2    1  ...    16    36   39    25     0    1    1
# X34_ANCA             2    1  ...    44    21   30    81     0    0    0
# X35_ANCA             4    1  ...     3    33   21    10     2    1    2
# X36_ANCA             4    5  ...    16   132  103    36     2    2    3
# X37_ANCA             4    3  ...    22    41   72    42     2    0    0
# X38_GBM              2    0  ...    15    75   67    36     3    3    1
# X39_SLE              5    3  ...   115   156  170   410     2    4    3
# X40_SLE              0    1  ...     8    17    8    13     0    0    1
# X41_Cntrl           15   19  ...    10    55   57    26     7   18    0
# X43_ANCA             0    2  ...     2    26   27    12     2    0    0
# X44_ANCA             0    0  ...     9    18    7     7     1    1    1
# X45_ANCA             1    1  ...     5    16    4    12     0    0    1
# X46_GBM              3    0  ...    10    74   19    12     1    0    0
# X47_SLE              8    3  ...     7    18   18    15     2    4    6
# X48_SLE              1    2  ...    33   106   74   185     1    4    2
# X49_ANCA             4    2  ...    18    55   47    50     1    2    1
# X50_ANCA             0    1  ...     6    32   21    13     0    0    0
# X51_ANCA             1    1  ...    12   109   61    22     0    1    1
# X52_ANCA             2    1  ...     6    15   10    15     2    1    4
# X53_ANCA             9   11  ...   120   420  321   244     2    7    2
# X54_SLE              2    2  ...    58   125   82   234     2    2    0
# X55_SLE              8    8  ...   115   297  136   347     3   10    4
# X56_SLE              1    0  ...     5    11   11     4     0    0    0
# X57_Cntrl           10   18  ...    25    72   47    90    13   23    5
# X58_ANCA             2    3  ...    26    86   39    22     1    3    0
# X60_ANCA             2    5  ...    33    52   63    81     2    1    1
# X61_SLE              0    1  ...    21    31   25   105     0    2    0
# X62_SLE              3    0  ...     9    25   21    36     0    0    1
# X63_ANCA            26   22  ...   198  1956  479   389    11   17    2
#
# celltype_l1        cycMNP  cycNKC/T  Patient_Sample_ID_col
# Patient_Sample_ID
# X1_Cntrl                4         2               X1_Cntrl
# X2_Cntrl                1         1               X2_Cntrl
# X3_ANCA                 9         0                X3_ANCA
# X4_ANCA                 4         1                X4_ANCA
# X6_ANCA                 0         0                X6_ANCA
# X7_SLE                  4         0                 X7_SLE
# X8_SLE                  1         0                 X8_SLE
# X9_Cntrl                1         0               X9_Cntrl
# X10_Cntrl               5         0              X10_Cntrl
# X12_ANCA                7         0               X12_ANCA
# X13_GBM                76         4                X13_GBM
# X14_ANCA                4         3               X14_ANCA
# X15_SLE                 1         3                X15_SLE
# X16_SLE                14         2                X16_SLE
# X17_ANCA               21         3               X17_ANCA
# X18_ANCA                5         0               X18_ANCA
# X19_ANCA               10         2               X19_ANCA
# X20_ANCA                2         1               X20_ANCA
# X21_GBM               620        35                X21_GBM
# X22_SLE                28         2                X22_SLE
# X23_SLE                 2         1                X23_SLE
# X24_SLE                14         1                X24_SLE
# X25_ANCA                8         0               X25_ANCA
# X26_ANCA                1         0               X26_ANCA
# X27_ANCA               75         8               X27_ANCA
# X28_ANCA                2         0               X28_ANCA
# X29_GBM                69        12                X29_GBM
# X30_SLE                 2         0                X30_SLE
# X31_SLE                12         1                X31_SLE
# X32_SLE                 0         0                X32_SLE
# X33_ANCA                7         2               X33_ANCA
# X34_ANCA                4         1               X34_ANCA
# X35_ANCA                7         1               X35_ANCA
# X36_ANCA               23         2               X36_ANCA
# X37_ANCA               13         2               X37_ANCA
# X38_GBM                20         0                X38_GBM
# X39_SLE                15         3                X39_SLE
# X40_SLE                 2         0                X40_SLE
# X41_Cntrl              15         4              X41_Cntrl
# X43_ANCA                8         0               X43_ANCA
# X44_ANCA                1         1               X44_ANCA
# X45_ANCA                4         1               X45_ANCA
# X46_GBM                12         2                X46_GBM
# X47_SLE                 1         1                X47_SLE
# X48_SLE                25         0                X48_SLE
# X49_ANCA               18         3               X49_ANCA
# X50_ANCA                1         0               X50_ANCA
# X51_ANCA               22         0               X51_ANCA
# X52_ANCA                1         0               X52_ANCA
# X53_ANCA              121         7               X53_ANCA
# X54_SLE                12         1                X54_SLE
# X55_SLE                46         4                X55_SLE
# X56_SLE                 2         1                X56_SLE
# X57_Cntrl              23         2              X57_Cntrl
# X58_ANCA               11         1               X58_ANCA
# X60_ANCA               15         4               X60_ANCA
# X61_SLE                 5         1                X61_SLE
# X62_SLE                 5         0                X62_SLE
# X63_ANCA              462        38               X63_ANCA
#
# [59 rows x 31 columns]

# %% [markdown]
# ## Convert the df to a AnnData object

# %%
data_Xen = dat.from_pandas(df_sampleXcelltypes, covariate_columns=["Patient_Sample_ID_col"])


print(data_Xen.X)
print(data_Xen.obs)
data_Xen
# Out:
# [[1974  313 1253 ...    2    4    2]
#  [ 268   43  175 ...    0    1    1]
#  [ 365  233   73 ...    0    9    0]
#  ...
#  [ 159   24   75 ...    0    5    1]
#  [ 239   51  211 ...    1    5    0]
#  [1860 2146  548 ...    2  462   38]]
# celltype_l1       Patient_Sample_ID_col
# Patient_Sample_ID
# X1_Cntrl                       X1_Cntrl
# X2_Cntrl                       X2_Cntrl
# X3_ANCA                         X3_ANCA
# X4_ANCA                         X4_ANCA
# X6_ANCA                         X6_ANCA
# X7_SLE                           X7_SLE
# X8_SLE                           X8_SLE
# X9_Cntrl                       X9_Cntrl
# X10_Cntrl                     X10_Cntrl
# X12_ANCA                       X12_ANCA
# X13_GBM                         X13_GBM
# X14_ANCA                       X14_ANCA
# X15_SLE                         X15_SLE
# X16_SLE                         X16_SLE
# X17_ANCA                       X17_ANCA
# X18_ANCA                       X18_ANCA
# X19_ANCA                       X19_ANCA
# X20_ANCA                       X20_ANCA
# X21_GBM                         X21_GBM
# X22_SLE                         X22_SLE
# X23_SLE                         X23_SLE
# X24_SLE                         X24_SLE
# X25_ANCA                       X25_ANCA
# X26_ANCA                       X26_ANCA
# X27_ANCA                       X27_ANCA
# X28_ANCA                       X28_ANCA
# X29_GBM                         X29_GBM
# X30_SLE                         X30_SLE
# X31_SLE                         X31_SLE
# X32_SLE                         X32_SLE
# X33_ANCA                       X33_ANCA
# X34_ANCA                       X34_ANCA
# X35_ANCA                       X35_ANCA
# X36_ANCA                       X36_ANCA
# X37_ANCA                       X37_ANCA
# X38_GBM                         X38_GBM
# X39_SLE                         X39_SLE
# X40_SLE                         X40_SLE
# X41_Cntrl                     X41_Cntrl
# X43_ANCA                       X43_ANCA
# X44_ANCA                       X44_ANCA
# X45_ANCA                       X45_ANCA
# X46_GBM                         X46_GBM
# X47_SLE                         X47_SLE
# X48_SLE                         X48_SLE
# X49_ANCA                       X49_ANCA
# X50_ANCA                       X50_ANCA
# X51_ANCA                       X51_ANCA
# X52_ANCA                       X52_ANCA
# X53_ANCA                       X53_ANCA
# X54_SLE                         X54_SLE
# X55_SLE                         X55_SLE
# X56_SLE                         X56_SLE
# X57_Cntrl                     X57_Cntrl
# X58_ANCA                       X58_ANCA
# X60_ANCA                       X60_ANCA
# X61_SLE                         X61_SLE
# X62_SLE                         X62_SLE
# X63_ANCA                       X63_ANCA
# AnnData object with n_obs × n_vars = 59 × 30
#     obs: 'Patient_Sample_ID_col'

# %%
adata.uns["celltype_l1_colors"]
# Out:
# array(['#800080', '#008080', '#FFD700', 'black', '#006400', '#20B2AA',
#        '#00BFFF', '#228B22', '#32CD32', '#90EE90', '#98FB98', '#00FA9A',
#        '#3CB371', '#4682B4', '#1E90FF', '#FFD700', '#DAA520', '#FF0000',
#        '#DC143C', '#4169E1', '#6495ED', '#800000', '#A52A2A', '#8B4513',
#        '#D2691E', '#FF1493', '#FF69B4', '#DB7093', '#FFB6C1', '#FFC0CB'],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sccoda.util import data_visualization as viz

# Extract the colors from adata
colors = adata.uns["celltype_l1_colors"]

# Convert the list of colors to a Matplotlib colormap
colormap = ListedColormap(colors)

plt.rcParams['figure.figsize'] = [18, 9]
viz.stacked_barplot(data=data_Xen, feature_name="Patient_Sample_ID_col", cmap=colormap)

# Customize fonts and plot
title_fontsize = 24
label_fontsize = 20
tick_fontsize = 10
legend_fontsize = 18

plt.title('Cell types: glomerular regions', fontsize=title_fontsize)
#plt.xlabel("")  # Remove x-axis label
plt.ylabel('Percentage', fontsize=label_fontsize)
plt.xticks(rotation=45, fontsize=tick_fontsize, ha='right', va='top')
plt.yticks(fontsize=tick_fontsize)
#plt.legend(title='Condition', title_fontsize=legend_fontsize, fontsize=legend_fontsize, bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.savefig("./output/Barplot_CellType_Percentages_glom.png")
plt.savefig("./output/Barplot_CellType_Percentages_glom.pdf")
plt.show()

# %%
df_sampleXcelltypes["condition"]=df_sampleXcelltypes["Patient_Sample_ID_col"].str.split("_").str[1]

con_order=['Cntrl', 'SLE', 'ANCA', 'GBM']
df_sampleXcelltypes["condition"]=pd.Categorical(df_sampleXcelltypes["condition"], categories=con_order, ordered=True)

# %%
cell_type_columns = df_sampleXcelltypes.columns.difference(['Patient_Sample_ID_col', 'condition'])
df_sampleXcelltypes['Total_Cells'] = df_sampleXcelltypes[cell_type_columns].sum(axis=1)

# ## Calculate Percentages
for col in cell_type_columns:
    df_sampleXcelltypes[col] = (df_sampleXcelltypes[col] / df_sampleXcelltypes['Total_Cells'])*100


df_sampleXcelltypes_long = df_sampleXcelltypes.melt(id_vars=['Patient_Sample_ID_col', 'condition'], 
                  value_vars=cell_type_columns, 
                  var_name='Cell_Type', 
                  value_name='Percentage')

df_sampleXcelltypes_long
# Out:
#      Patient_Sample_ID_col condition Cell_Type  Percentage
# 0                 X1_Cntrl     Cntrl       ATL    0.075735
# 1                 X2_Cntrl     Cntrl       ATL    0.000000
# 2                  X3_ANCA      ANCA       ATL    0.000000
# 3                  X4_ANCA      ANCA       ATL    0.000000
# 4                  X6_ANCA      ANCA       ATL    0.180832
# ...                    ...       ...       ...         ...
# 1765              X58_ANCA      ANCA  podocyte   26.634615
# 1766              X60_ANCA      ANCA  podocyte   24.674761
# 1767               X61_SLE       SLE  podocyte   18.794326
# 1768               X62_SLE       SLE  podocyte   21.001757
# 1769              X63_ANCA      ANCA  podocyte   15.681646
#
# [1770 rows x 4 columns]

# %%
custom_palette = {
    'Cntrl': '#0173b2',  
    'SLE': '#E3A5D6FF',   
    'ANCA': '#029e73',   
    'GBM': '#d55e00'     
}

#cell_type_order = [
#    'podocyte', 'PEC', 'MC', 'Fibrotic MC', 'EC','VSM/P',
#    'T', 'NKC/T', 'B', 'PL', 'N', 'MAC', 'MDC', 'Mono', 'MAST', 'cDC', 'pDC', 'cycMNP', 'cycNKC/T', 
#    'PapE', 'PT', 'ATL', 'CNT', 'DCT', 'DTL', 'TAL', 'IC', 'NEU', 'PC'
#]

cell_type_order = [
    'podocyte', 'PEC', 'EC','VSM/P','MC','Fibrotic MC',
    'T', 'NKC/T', 'B', 'PL', 'N', 'MAC', 'MDC', 'Mono', 'MAST', 'cDC', 'pDC', 'cycMNP', 'cycNKC/T', 
    'PapE', 'PT', 'ATL', 'CNT', 'DCT', 'DTL', 'TAL', 'IC', 'NEU', 'PC'
]




plt.figure(figsize=(20, 8))
sns.boxplot(
    data=df_sampleXcelltypes_long, 
    x='Cell_Type', 
    y='Percentage', 
    hue='condition', 
    palette=custom_palette, 
    order=cell_type_order,
    showfliers=False  
)


title_fontsize = 28
label_fontsize = 22
tick_fontsize = 20
legend_fontsize = 18

plt.title('Cell types: glomerular regions', fontsize=title_fontsize)
plt.xlabel("") 
plt.ylabel('Percentage', fontsize=label_fontsize)
plt.xticks(rotation=45, fontsize=tick_fontsize, ha='right', va='top')
plt.yticks(fontsize=tick_fontsize)
plt.legend(title='Condition', title_fontsize=legend_fontsize, fontsize=legend_fontsize, bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.savefig("./output/Boxplot_CellType_Percentages_glom.png")
plt.savefig("./output/Boxplot_CellType_Percentages_glom.pdf")
plt.show()

# %% [markdown]
# ## Plot without Tubular Cells

# %%
cell_type_order = [
    'podocyte', 'PEC', 'MC', 'Fibrotic MC', 'EC','VSM/P',
    'T', 'NKC/T', 'B', 'PL', 'N', 'MAC', 'MDC', 'Mono', 'MAST', 'cDC', 'pDC', 'cycMNP', 'cycNKC/T'
    
    #, 'PapE', 'PT', 'ATL', 'CNT', 'DCT', 'DTL', 'TAL', 'IC', 'NEU', 'PC'
]

# Step 4: Create the boxplot
plt.figure(figsize=(20, 8))
sns.boxplot(
    data=df_sampleXcelltypes_long, 
    x='Cell_Type', 
    y='Percentage', 
    hue='condition', 
    palette=custom_palette, 
    order=cell_type_order,
    showfliers=False  # Suppress outliers
)

# Customize fonts and plot
title_fontsize = 28
label_fontsize = 22
tick_fontsize = 20
legend_fontsize = 18

plt.title('Cell types: glomerular regions', fontsize=title_fontsize)
plt.xlabel("")  
plt.ylabel('Percentage', fontsize=label_fontsize)
plt.xticks(rotation=45, fontsize=tick_fontsize, ha='right', va='top')
plt.yticks(fontsize=tick_fontsize)
plt.legend(title='Condition', title_fontsize=legend_fontsize, fontsize=legend_fontsize, bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.savefig("./output/Boxplot_CellType_Percentages_glom_NoTubules.png")
plt.savefig("./output/Boxplot_CellType_Percentages_glom_NoTubules.pdf")
plt.show()

# %%
df_sampleXcelltypes_long
# Out:
#      Patient_Sample_ID_col condition Cell_Type  Percentage
# 0                 X1_Cntrl     Cntrl       ATL    0.075735
# 1                 X2_Cntrl     Cntrl       ATL    0.000000
# 2                  X3_ANCA      ANCA       ATL    0.000000
# 3                  X4_ANCA      ANCA       ATL    0.000000
# 4                  X6_ANCA      ANCA       ATL    0.180832
# ...                    ...       ...       ...         ...
# 1765              X58_ANCA      ANCA  podocyte   26.634615
# 1766              X60_ANCA      ANCA  podocyte   24.674761
# 1767               X61_SLE       SLE  podocyte   18.794326
# 1768               X62_SLE       SLE  podocyte   21.001757
# 1769              X63_ANCA      ANCA  podocyte   15.681646
#
# [1770 rows x 4 columns]

# %%
median_Percentage = df_sampleXcelltypes_long.groupby(['condition', 'Cell_Type'])['Percentage'].median().reset_index()

# %%
median_Percentage.to_csv('./output/median_Percentage_celltype_GLOM.csv')

# %%
filtered_df = median_Percentage[median_Percentage['Cell_Type'] == 'podocyte']
#filtered_df['perc']=filtered_df.Percentage*100
filtered_df
# Out:
#     condition Cell_Type  Percentage
# 29      Cntrl  podocyte   30.142759
# 59        SLE  podocyte   25.925926
# 89       ANCA  podocyte   25.349198
# 119       GBM  podocyte   23.817713
