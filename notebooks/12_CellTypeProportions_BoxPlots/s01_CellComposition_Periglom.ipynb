# %%
import importlib
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import scanpy as sc
import seaborn as sns

from sccoda.util import comp_ana as mod
from sccoda.util import cell_composition_data as dat
from sccoda.util import data_visualization as viz


import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sccoda.util import data_visualization as viz
# Out:
# 2025-05-25 10:48:56.559210: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-25 10:48:56.599877: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-25 10:48:56.599909: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-25 10:48:56.601128: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 10:48:56.607755: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-25 10:48:56.608401: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-25 10:48:57.463168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
out_folder = './output'
os.makedirs(out_folder, exist_ok=True)

# %%
# the following are needed to ensure that text in plt images opens as text box rather than glyphs in adobe
plt.rcParams['pdf.fonttype'] = 42  
plt.rcParams['ps.fonttype'] = 42

# %%
# !pwd
# Out:
# /data/projects/zeba/MY_PROJECTS/240130_Xenium_ANCA_SLE_GBM/xenium-cgn-zeba-may25/xenium-cgn/notebooks/12_CellTypeProportions_BoxPlots

# %% [markdown]
# ## AnnData Object with everything
# Shared by Robin on 31 Oct Slack with me:
# /data/projects/robin/segmentation/xenium_outs/adata_complete_reduced_withTransformedMC.h5ad
# This is also the object that I have used for the Cellchat Analysis

# %%
#adata = sc.read_h5ad("/data/projects/robin/segmentation/xenium_outs/adata_complete_reduced_withTransformedMC.h5ad")
adata = sc.read_h5ad('/data/projects/zeba/MY_PROJECTS/240130_Xenium_ANCA_SLE_GBM/xenium-cgn/notebooks_zs/02_PeriglomDefinition_Sample26updated/output_dataobjects/adata_complete_reduced_withTransformedMC_X26updated.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 3218210 × 480
#     obs: 'x', 'y', 'z', 'cluster', 'n_transcripts', 'density', 'elongation', 'area', 'avg_confidence', 'avg_assignment_confidence', 'max_cluster_frac', 'lifespan', 'x_centroid', 'y_centroid', 'cell_area', 'Slide_ID', 'batch', 'Patient_Sample_ID', 'Disease', 'n_genes', 'celltype_l1', 'celltype_l1_codes', 'celltype_l1_prob', 'Biopsy_ID', 'sample', 'label', 'nichepca_domain', 'nichepca_domain_tuned', 'nichepca_glom_no', 'glom_ID', 'polygon_flags', 'is_in_polygon', 'is_in_glom', 'is_in_periglom', 'Slide_num'
#     var: 'gene_ids', 'feature_types'
#     uns: 'celltype_l1_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'

# %%
rename_dict = {
    "Transformed mesangial": "Fibrotic MC",
    "mesangial cell": "MC",
}


adata.obs["celltype_l1"] = adata.obs["celltype_l1"].replace(rename_dict)

# %% [markdown]
# ### Subset Cell in periglomerular regions

# %%
adata=adata[adata.obs['is_in_periglom']==True]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 435904 × 480
#     obs: 'x', 'y', 'z', 'cluster', 'n_transcripts', 'density', 'elongation', 'area', 'avg_confidence', 'avg_assignment_confidence', 'max_cluster_frac', 'lifespan', 'x_centroid', 'y_centroid', 'cell_area', 'Slide_ID', 'batch', 'Patient_Sample_ID', 'Disease', 'n_genes', 'celltype_l1', 'celltype_l1_codes', 'celltype_l1_prob', 'Biopsy_ID', 'sample', 'label', 'nichepca_domain', 'nichepca_domain_tuned', 'nichepca_glom_no', 'glom_ID', 'polygon_flags', 'is_in_polygon', 'is_in_glom', 'is_in_periglom', 'Slide_num'
#     var: 'gene_ids', 'feature_types'
#     uns: 'celltype_l1_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'

# %%
adata.obs["Patient_Sample_ID"]
# Out:
# cell_CR4f0dee9aa-1334        X8_SLE
# cell_CR4f0dee9aa-1340        X8_SLE
# cell_CR4f0dee9aa-1373        X8_SLE
# cell_CR4f0dee9aa-1397        X8_SLE
# cell_CR4f0dee9aa-1421        X8_SLE
#                              ...
# cell_CR4113b3b6d-452577    X63_ANCA
# cell_CR4113b3b6d-452743    X63_ANCA
# cell_CR4113b3b6d-453127    X58_ANCA
# cell_CR4113b3b6d-453235    X63_ANCA
# cell_CR4113b3b6d-453890    X63_ANCA
# Name: Patient_Sample_ID, Length: 435904, dtype: category
# Categories (59, object): ['X1_Cntrl', 'X2_Cntrl', 'X3_ANCA', 'X4_ANCA', ..., 'X60_ANCA', 'X61_SLE', 'X62_SLE', 'X63_ANCA']

# %%
df_sample_celltypes = adata.obs[["Patient_Sample_ID","celltype_l1"]]
df_sample_celltypes
# Out:
#                         Patient_Sample_ID celltype_l1
# cell_CR4f0dee9aa-1334              X8_SLE          PT
# cell_CR4f0dee9aa-1340              X8_SLE         CNT
# cell_CR4f0dee9aa-1373              X8_SLE         MAC
# cell_CR4f0dee9aa-1397              X8_SLE         CNT
# cell_CR4f0dee9aa-1421              X8_SLE          EC
# ...                                   ...         ...
# cell_CR4113b3b6d-452577          X63_ANCA         FIB
# cell_CR4113b3b6d-452743          X63_ANCA          EC
# cell_CR4113b3b6d-453127          X58_ANCA         FIB
# cell_CR4113b3b6d-453235          X63_ANCA       VSM/P
# cell_CR4113b3b6d-453890          X63_ANCA         FIB
#
# [435904 rows x 2 columns]

# %%
df_sampleXcelltypes = df_sample_celltypes.groupby(["Patient_Sample_ID","celltype_l1"]).size().reset_index(name='counts')
df_sampleXcelltypes
# Out:
#      Patient_Sample_ID celltype_l1  counts
# 0             X1_Cntrl    podocyte      53
# 1             X1_Cntrl         PEC     771
# 2             X1_Cntrl          MC      95
# 3             X1_Cntrl        PapE      31
# 4             X1_Cntrl       VSM/P     944
# ...                ...         ...     ...
# 1706          X63_ANCA        MAST      64
# 1707          X63_ANCA         cDC     184
# 1708          X63_ANCA         pDC      25
# 1709          X63_ANCA      cycMNP     556
# 1710          X63_ANCA    cycNKC/T      48
#
# [1711 rows x 3 columns]

# %%
df_sampleXcelltypes = df_sampleXcelltypes.pivot(index= "Patient_Sample_ID", columns="celltype_l1", values="counts").fillna(0)
df_sampleXcelltypes = df_sampleXcelltypes.astype(int)

# %%
df_sampleXcelltypes["Patient_Sample_ID_col"]=df_sampleXcelltypes.index

# %%
df_sampleXcelltypes
# Out:
# celltype_l1        podocyte  PEC   MC  PapE  VSM/P    EC    PT  ATL   CNT  \
# Patient_Sample_ID
# X1_Cntrl                 53  771   95    31    944  1417  3666   14   914
# X2_Cntrl                 48   82   29    13     74   240   575    7    72
# X3_ANCA                  35  122   54    20    133   445   980    7   201
# X4_ANCA                  27   80   20    20    122   303   567    6   112
# X6_ANCA                  33   72   14     7     86   242   743    3    83
# X7_SLE                   33  145   18    15     89   329   821    6   109
# X8_SLE                    2    2    1     1      3    10    12    1     9
# X9_Cntrl                 44   91   62    34    215   439   962    7   351
# X10_Cntrl               140  418  123    38    533  1981  8368   35  1102
# X12_ANCA                 10   30    6    14     60   168   634    2    85
# X13_GBM                  67  173   43    69    371   592  1317   46   548
# X14_ANCA                 32  134   27    25    106   425  1172    3   328
# X15_SLE                  46   92   33    17    166   539  1573   10   141
# X16_SLE                  34  125   16    13    156   540  1846    8   172
# X17_ANCA                 62  154   27    57    224   522  1497    9   210
# X18_ANCA                 36   76   23    25    157   205   252    7    55
# X19_ANCA                 18   64    5     8     53   230   289    4    29
# X20_ANCA                 34   67   46    17     47   204   313   12    34
# X21_GBM                 157  481   86   249    761  2292  4414  132   808
# X22_SLE                  97  276   49    20    336  1491  3867    9   238
# X23_SLE                  24   62    1     0     17   134   379    0    12
# X24_SLE                 121  278   47    32    237  1892  4503    8   386
# X25_ANCA                 21   61   24    12    139   233   592   11    35
# X26_ANCA                156  499   99    46    309   674  1323   10   146
# X27_ANCA                 53  203   62    37    460   889  2325   29   407
# X28_ANCA                 20   62    7    22     70   253   834    4    47
# X29_GBM                  70  191   47   168    828  1710  5632   52  1403
# X30_SLE                  98  141   36    25    230   732  1610    4   345
# X31_SLE                 131  361   87    48    518  1995  4845   18   580
# X32_SLE                  19   38    7     2     39   177   384    2    38
# X33_ANCA                 38   59   31    29    246   644  1168    7   145
# X34_ANCA                 33  170   14    60    346   343   758   13   126
# X35_ANCA                 51  180   39    35    197   716  1412    9   186
# X36_ANCA                 44  199   15    49    177   511  1508   17   309
# X37_ANCA                 44  289   40    51    298   604  1711   15   361
# X38_GBM                  37  127   12    48    272   345   790   15   183
# X39_SLE                 185  762   43    35    564  1722  4524   14   435
# X40_SLE                  21   47    4     0     89   358   942    4    82
# X41_Cntrl               103  179   80    70    370  1227  2324   19   862
# X43_ANCA                 22   53   26    20    148   362   888    9    96
# X44_ANCA                 24  103   32    23    138   294   452    8   117
# X45_ANCA                111  210   44    36    375   500  1155   13   133
# X46_GBM                  23   85    4     3     38   218   616    5    61
# X47_SLE                  70  145   67    17    263  1338  2448   15   544
# X48_SLE                  18   88   26     6    134   264   702    4    79
# X49_ANCA                 82  157   37    27    438   981  2301    4   178
# X50_ANCA                 13   38    9     6     43   164   353    1    74
# X51_ANCA                 42   71   46    37    190   538   846   11   197
# X52_ANCA                 52  128   23    22    146   381   964    3    79
# X53_ANCA                 49  218   30   101    338  1308  2097   21   703
# X54_SLE                  26  189   19    10     90   745  1609    1    74
# X55_SLE                  83  258   50    50    486  1695  4247    8   235
# X56_SLE                  42   39   12    11     87   414   967    3   118
# X57_Cntrl               162  417  140    98    701  1524  2307   51   653
# X58_ANCA                 49  161   44    54    532   842  1982   11   288
# X60_ANCA                 65   97   75    41    306   868  1587    6   243
# X61_SLE                   6   35    2     0     29   118   276    0    27
# X62_SLE                  32   60   53    12    207   294   518    5    57
# X63_ANCA                134  328   61   102    524  1642  2993   66   806
#
# celltype_l1         DCT  ...     N   MAC   MDC  Mono  MAST  cDC  pDC  cycMNP  \
# Patient_Sample_ID        ...
# X1_Cntrl            500  ...    21   507   240    62    38   62   19      17
# X2_Cntrl            114  ...     7    77    32    13    13    5    2       8
# X3_ANCA              98  ...    43   370   353   123    18   45   13      52
# X4_ANCA              37  ...    25   212   245    57    55   26   12      13
# X6_ANCA              30  ...    19   157    20    11     8    7    0       4
# X7_SLE              124  ...    29   261    88    30     7   10    5      12
# X8_SLE               11  ...     1     6     0     4     1    0    0       0
# X9_Cntrl            377  ...    17   176    40    19    13    9    5       7
# X10_Cntrl           625  ...    37   489    48    56    29   52   11      26
# X12_ANCA             30  ...    20   193   136    50     8   15    2      18
# X13_GBM              92  ...   345  1272   529   432    31   35    9     102
# X14_ANCA            124  ...    92   832   335   227    11   25    8     105
# X15_SLE             184  ...    38   285   148    68    17   20    6      28
# X16_SLE              73  ...    31   701   112    41     4   18    2      34
# X17_ANCA            237  ...   125   829   392   159    53   42   11      95
# X18_ANCA              5  ...    36   221   219    89    25   18    7      28
# X19_ANCA             10  ...    84   574   333   148     5   31    4     102
# X20_ANCA             27  ...    23   129   100    49    27   22    5      22
# X21_GBM             132  ...  1349  5145  1808  1153    71  179   19     797
# X22_SLE             387  ...    75   457   182   115    20   31    6      36
# X23_SLE              15  ...     7    64    25    14     2    4    0       6
# X24_SLE             485  ...    68  1005   284   210    12   95   16      79
# X25_ANCA              3  ...    46   335   175    60    12   10    1      35
# X26_ANCA            124  ...    47   630   317   115    32   27   13      59
# X27_ANCA            131  ...   145  1654   739   311    32  120   22     269
# X28_ANCA            126  ...    11   239    93    38    10   15    3      28
# X29_GBM             451  ...   105  1530   287   175    30   43    5     172
# X30_SLE             266  ...    45   391   148    52    11   18    6      34
# X31_SLE             378  ...   110  1169   448   242    31   96   12      96
# X32_SLE               8  ...    12   118    87    26    14   16   12      11
# X33_ANCA            115  ...    47   547   525   101    35   57   12      41
# X34_ANCA             48  ...    74   427   431   115    35   24    6      26
# X35_ANCA            114  ...    34   535   258    61    48   27    5      42
# X36_ANCA            101  ...    66  1133   551   155    30   36   11      86
# X37_ANCA            129  ...   153   898  1084   445    59  104   39     115
# X38_GBM              84  ...    54   524   308   123    20   27    5      40
# X39_SLE             574  ...    86  1094   469   208    10   45   11      73
# X40_SLE              36  ...    11   178    44     7     7    9    0       5
# X41_Cntrl          1209  ...    37   306   135    51    40   30   10      41
# X43_ANCA             47  ...    43   470   222    64    10   15    2      39
# X44_ANCA              7  ...    33   622   163    59    17   17    4      44
# X45_ANCA             19  ...    46   646   152    72    17   26    7      33
# X46_GBM              29  ...    36   477   113    43     2    5    3      38
# X47_SLE             414  ...    51   347   130   100     8   45   13      17
# X48_SLE              62  ...    18   162    82    40    11    7    2      11
# X49_ANCA            139  ...    46   650   578   111    45   43   12      40
# X50_ANCA              5  ...    15   144    73    31     1    5    2      15
# X51_ANCA             24  ...    65   773   345   133    63   28    5     108
# X52_ANCA             58  ...    75   300   120    52    19   19    9      54
# X53_ANCA            155  ...   247  3075  1724   597    53  146   79     248
# X54_SLE              61  ...    65   733   243   202    18   39    6      80
# X55_SLE             275  ...   109  1405   647   319    30   88   40     136
# X56_SLE             102  ...     9    84    57    12     2   18    1       2
# X57_Cntrl           629  ...    76   468   342   147   102  127   22      76
# X58_ANCA             74  ...    90  1125   259   134    32   42   11     115
# X60_ANCA            197  ...    52   463   276    83    56   55   20      58
# X61_SLE               0  ...     9   126    41    19     0    4    0       8
# X62_SLE              44  ...    21   223    92    29    11    8    1      17
# X63_ANCA            159  ...   385  4421  1238   435    64  184   25     556
#
# celltype_l1        cycNKC/T  Patient_Sample_ID_col
# Patient_Sample_ID
# X1_Cntrl                  3               X1_Cntrl
# X2_Cntrl                  1               X2_Cntrl
# X3_ANCA                   8                X3_ANCA
# X4_ANCA                   2                X4_ANCA
# X6_ANCA                   2                X6_ANCA
# X7_SLE                    3                 X7_SLE
# X8_SLE                    0                 X8_SLE
# X9_Cntrl                  1               X9_Cntrl
# X10_Cntrl                 4              X10_Cntrl
# X12_ANCA                  3               X12_ANCA
# X13_GBM                  18                X13_GBM
# X14_ANCA                  9               X14_ANCA
# X15_SLE                   7                X15_SLE
# X16_SLE                   5                X16_SLE
# X17_ANCA                 19               X17_ANCA
# X18_ANCA                  3               X18_ANCA
# X19_ANCA                  5               X19_ANCA
# X20_ANCA                  1               X20_ANCA
# X21_GBM                 152                X21_GBM
# X22_SLE                   5                X22_SLE
# X23_SLE                   0                X23_SLE
# X24_SLE                   7                X24_SLE
# X25_ANCA                  4               X25_ANCA
# X26_ANCA                 10               X26_ANCA
# X27_ANCA                 38               X27_ANCA
# X28_ANCA                  3               X28_ANCA
# X29_GBM                  20                X29_GBM
# X30_SLE                   6                X30_SLE
# X31_SLE                  12                X31_SLE
# X32_SLE                   1                X32_SLE
# X33_ANCA                  9               X33_ANCA
# X34_ANCA                  3               X34_ANCA
# X35_ANCA                  7               X35_ANCA
# X36_ANCA                  7               X36_ANCA
# X37_ANCA                 14               X37_ANCA
# X38_GBM                   8                X38_GBM
# X39_SLE                  14                X39_SLE
# X40_SLE                   2                X40_SLE
# X41_Cntrl                 2              X41_Cntrl
# X43_ANCA                  4               X43_ANCA
# X44_ANCA                  4               X44_ANCA
# X45_ANCA                  8               X45_ANCA
# X46_GBM                   6                X46_GBM
# X47_SLE                   7                X47_SLE
# X48_SLE                   2                X48_SLE
# X49_ANCA                  6               X49_ANCA
# X50_ANCA                  0               X50_ANCA
# X51_ANCA                  6               X51_ANCA
# X52_ANCA                  7               X52_ANCA
# X53_ANCA                 29               X53_ANCA
# X54_SLE                  19                X54_SLE
# X55_SLE                  22                X55_SLE
# X56_SLE                   0                X56_SLE
# X57_Cntrl                 4              X57_Cntrl
# X58_ANCA                 11               X58_ANCA
# X60_ANCA                  8               X60_ANCA
# X61_SLE                   2                X61_SLE
# X62_SLE                   2                X62_SLE
# X63_ANCA                 48               X63_ANCA
#
# [59 rows x 30 columns]

# %% [markdown]
# ## Convert the df to a AnnData object

# %%
data_Xen = dat.from_pandas(df_sampleXcelltypes, covariate_columns=["Patient_Sample_ID_col"])

# Extract condition from mouse name and add it as an extra column to the covariates
#data_mouse.obs["Condition"] = data_mouse.obs["Mouse"].str.replace(r"_[0-9]", "", regex=True)
print(data_Xen.X)
print(data_Xen.obs)
data_Xen
# Out:
# [[ 53 771  95 ...  19  17   3]
#  [ 48  82  29 ...   2   8   1]
#  [ 35 122  54 ...  13  52   8]
#  ...
#  [  6  35   2 ...   0   8   2]
#  [ 32  60  53 ...   1  17   2]
#  [134 328  61 ...  25 556  48]]
# celltype_l1       Patient_Sample_ID_col
# Patient_Sample_ID
# X1_Cntrl                       X1_Cntrl
# X2_Cntrl                       X2_Cntrl
# X3_ANCA                         X3_ANCA
# X4_ANCA                         X4_ANCA
# X6_ANCA                         X6_ANCA
# X7_SLE                           X7_SLE
# X8_SLE                           X8_SLE
# X9_Cntrl                       X9_Cntrl
# X10_Cntrl                     X10_Cntrl
# X12_ANCA                       X12_ANCA
# X13_GBM                         X13_GBM
# X14_ANCA                       X14_ANCA
# X15_SLE                         X15_SLE
# X16_SLE                         X16_SLE
# X17_ANCA                       X17_ANCA
# X18_ANCA                       X18_ANCA
# X19_ANCA                       X19_ANCA
# X20_ANCA                       X20_ANCA
# X21_GBM                         X21_GBM
# X22_SLE                         X22_SLE
# X23_SLE                         X23_SLE
# X24_SLE                         X24_SLE
# X25_ANCA                       X25_ANCA
# X26_ANCA                       X26_ANCA
# X27_ANCA                       X27_ANCA
# X28_ANCA                       X28_ANCA
# X29_GBM                         X29_GBM
# X30_SLE                         X30_SLE
# X31_SLE                         X31_SLE
# X32_SLE                         X32_SLE
# X33_ANCA                       X33_ANCA
# X34_ANCA                       X34_ANCA
# X35_ANCA                       X35_ANCA
# X36_ANCA                       X36_ANCA
# X37_ANCA                       X37_ANCA
# X38_GBM                         X38_GBM
# X39_SLE                         X39_SLE
# X40_SLE                         X40_SLE
# X41_Cntrl                     X41_Cntrl
# X43_ANCA                       X43_ANCA
# X44_ANCA                       X44_ANCA
# X45_ANCA                       X45_ANCA
# X46_GBM                         X46_GBM
# X47_SLE                         X47_SLE
# X48_SLE                         X48_SLE
# X49_ANCA                       X49_ANCA
# X50_ANCA                       X50_ANCA
# X51_ANCA                       X51_ANCA
# X52_ANCA                       X52_ANCA
# X53_ANCA                       X53_ANCA
# X54_SLE                         X54_SLE
# X55_SLE                         X55_SLE
# X56_SLE                         X56_SLE
# X57_Cntrl                     X57_Cntrl
# X58_ANCA                       X58_ANCA
# X60_ANCA                       X60_ANCA
# X61_SLE                         X61_SLE
# X62_SLE                         X62_SLE
# X63_ANCA                       X63_ANCA
# AnnData object with n_obs × n_vars = 59 × 29
#     obs: 'Patient_Sample_ID_col'

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sccoda.util import data_visualization as viz

# Extract the colors from adata
colors = adata.uns["celltype_l1_colors"]

# Convert the list of colors to a Matplotlib colormap
colormap = ListedColormap(colors)

plt.rcParams['figure.figsize'] = [18, 9]
viz.stacked_barplot(data=data_Xen, feature_name="Patient_Sample_ID_col", cmap=colormap)

# Customize fonts and plot
title_fontsize = 24
label_fontsize = 20
#tick_fontsize = 10
xtick_fontsize = 12
ytick_fontsize = 20
legend_fontsize = 18

plt.title('Cell types: periglomerular regions', fontsize=title_fontsize)
#plt.xlabel("")  # Remove x-axis label
plt.ylabel('Percentage', fontsize=label_fontsize)
plt.xticks(rotation=45, fontsize=xtick_fontsize, ha='right', va='top')
plt.yticks(fontsize=ytick_fontsize)
#plt.legend(title='Condition', title_fontsize=legend_fontsize, fontsize=legend_fontsize, bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.savefig("./output/Barplot_CellType_Percentages_periglom.png")
plt.savefig("./output/Barplot_CellType_Percentages_periglom.pdf")
plt.show()

# %%
df_sampleXcelltypes["condition"]=df_sampleXcelltypes["Patient_Sample_ID_col"].str.split("_").str[1]

con_order=['Cntrl', 'SLE', 'ANCA', 'GBM']
df_sampleXcelltypes["condition"]=pd.Categorical(df_sampleXcelltypes["condition"], categories=con_order, ordered=True)

# %%
cell_type_columns = df_sampleXcelltypes.columns.difference(['Patient_Sample_ID_col', 'condition'])
df_sampleXcelltypes['Total_Cells'] = df_sampleXcelltypes[cell_type_columns].sum(axis=1)

# ## Calculate Percentages
for col in cell_type_columns:
    df_sampleXcelltypes[col] = (df_sampleXcelltypes[col] / df_sampleXcelltypes['Total_Cells'])*100


df_sampleXcelltypes_long = df_sampleXcelltypes.melt(id_vars=['Patient_Sample_ID_col', 'condition'], 
                  value_vars=cell_type_columns, 
                  var_name='Cell_Type', 
                  value_name='Percentage')

df_sampleXcelltypes_long
# Out:
#      Patient_Sample_ID_col condition Cell_Type  Percentage
# 0                 X1_Cntrl     Cntrl       ATL    0.109692
# 1                 X2_Cntrl     Cntrl       ATL    0.331911
# 2                  X3_ANCA      ANCA       ATL    0.135161
# 3                  X4_ANCA      ANCA       ATL    0.201613
# 4                  X6_ANCA      ANCA       ATL    0.148221
# ...                    ...       ...       ...         ...
# 1706              X58_ANCA      ANCA  podocyte    0.535519
# 1707              X60_ANCA      ANCA  podocyte    0.952241
# 1708               X61_SLE       SLE  podocyte    0.589971
# 1709               X62_SLE       SLE  podocyte    1.302401
# 1710              X63_ANCA      ANCA  podocyte    0.579184
#
# [1711 rows x 4 columns]

# %%
list(adata.obs['celltype_l1'].unique())
# Out:
# ['PT',
#  'CNT',
#  'MAC',
#  'EC',
#  'PL',
#  'T',
#  'IC',
#  'DTL',
#  'PEC',
#  'FIB',
#  'NKC/T',
#  'podocyte',
#  'DCT',
#  'VSM/P',
#  'MC',
#  'Mono',
#  'PapE',
#  'B',
#  'ATL',
#  'N',
#  'cycMNP',
#  'MDC',
#  'PC',
#  'cDC',
#  'TAL',
#  'cycNKC/T',
#  'pDC',
#  'MAST',
#  'NEU']

# %%
custom_palette = {
    'Cntrl': '#0173b2',  
    'SLE': '#E3A5D6FF',   
    'ANCA': '#029e73',   
    'GBM': '#d55e00'     
}

cell_type_order = [
    'podocyte', 'PEC', 'EC','VSM/P','MC','FIB',
    'T', 'NKC/T', 'B', 'PL', 'N', 'MAC', 'MDC', 'Mono', 'MAST', 'cDC', 'pDC', 'cycMNP', 'cycNKC/T', 
    'PapE', 'PT', 'ATL', 'CNT', 'DCT', 'DTL', 'TAL', 'IC', 'NEU', 'PC'
]


plt.figure(figsize=(20, 8))
sns.boxplot(
    data=df_sampleXcelltypes_long, 
    x='Cell_Type', 
    y='Percentage', 
    hue='condition', 
    palette=custom_palette, 
    order=cell_type_order,
    showfliers=False  
)


title_fontsize = 28
label_fontsize = 22
tick_fontsize = 20
legend_fontsize = 18

plt.title('Cell types: periglomerular regions', fontsize=title_fontsize)
plt.xlabel("") 
plt.ylabel('Percentage', fontsize=label_fontsize)
plt.xticks(rotation=45, fontsize=tick_fontsize, ha='right', va='top')
plt.yticks(fontsize=tick_fontsize)
plt.legend(title='Condition', title_fontsize=legend_fontsize, fontsize=legend_fontsize, bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.savefig("./output/Boxplot_CellType_Percentages_periglom.png")
plt.savefig("./output/Boxplot_CellType_Percentages_periglom.pdf")
plt.show()

# %% [markdown]
# ## Plot without Tubular Cells

# %%
cell_type_order = [
    'podocyte', 'PEC', 'MC', 'Fibrotic MC', 'EC','VSM/P',
    'T', 'NKC/T', 'B', 'PL', 'N', 'MAC', 'MDC', 'Mono', 'MAST', 'cDC', 'pDC', 'cycMNP', 'cycNKC/T'
    
    #, 'PapE', 'PT', 'ATL', 'CNT', 'DCT', 'DTL', 'TAL', 'IC', 'NEU', 'PC'
]

# Step 4: Create the boxplot
plt.figure(figsize=(20, 8))
sns.boxplot(
    data=df_sampleXcelltypes_long, 
    x='Cell_Type', 
    y='Percentage', 
    hue='condition', 
    palette=custom_palette, 
    order=cell_type_order,
    showfliers=False  # Suppress outliers
)

# Customize fonts and plot
title_fontsize = 28
label_fontsize = 22
tick_fontsize = 20
legend_fontsize = 18

plt.title('Cell types: periglomerular regions', fontsize=title_fontsize)
plt.xlabel("")  
plt.ylabel('Percentage', fontsize=label_fontsize)
plt.xticks(rotation=45, fontsize=tick_fontsize, ha='right', va='top')
plt.yticks(fontsize=tick_fontsize)
plt.legend(title='Condition', title_fontsize=legend_fontsize, fontsize=legend_fontsize, bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.savefig("./output/Boxplot_CellType_Percentages_periglom_NoTubules.png")
plt.savefig("./output/Boxplot_CellType_Percentages_periglom_NoTubules.pdf")
plt.show()

# %%
df_sampleXcelltypes_long
# Out:
#      Patient_Sample_ID_col condition Cell_Type  Percentage
# 0                 X1_Cntrl     Cntrl       ATL    0.109692
# 1                 X2_Cntrl     Cntrl       ATL    0.331911
# 2                  X3_ANCA      ANCA       ATL    0.135161
# 3                  X4_ANCA      ANCA       ATL    0.201613
# 4                  X6_ANCA      ANCA       ATL    0.148221
# ...                    ...       ...       ...         ...
# 1706              X58_ANCA      ANCA  podocyte    0.535519
# 1707              X60_ANCA      ANCA  podocyte    0.952241
# 1708               X61_SLE       SLE  podocyte    0.589971
# 1709               X62_SLE       SLE  podocyte    1.302401
# 1710              X63_ANCA      ANCA  podocyte    0.579184
#
# [1711 rows x 4 columns]

# %%
median_Percentage = df_sampleXcelltypes_long.groupby(['condition', 'Cell_Type'])['Percentage'].median().reset_index()

# %%
median_Percentage.to_csv('./output/median_Percentage_celltype_PERIGLOM.csv')

# %%
filtered_df = median_Percentage[median_Percentage['Cell_Type'] == 'podocyte']
#filtered_df['perc']=filtered_df.Percentage*100
filtered_df
# Out:
#     condition Cell_Type  Percentage
# 28      Cntrl  podocyte    1.025617
# 57        SLE  podocyte    0.903555
# 86       ANCA  podocyte    0.672098
# 115       GBM  podocyte    0.624069
